# %%
# Load libraries
import numpy as np
from keras import models
from keras import layers
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_classification
import keras
import csv
import pandas as pd 
from scikeras.wrappers import KerasClassifier, KerasRegressor

# Set random seed
np.random.seed(0)

# %%
#open and read file

#file = open('DATA.csv')

#csvreader = csv.reader(file)
data= pd.read_csv("DATA.csv", delimiter=';')
data
# Out:
#      STUDENT ID  1  2  3  4  5  6  7  8  9  ...  23  24  25  26  27  28  29  \
# 0      STUDENT1  2  2  3  3  1  2  2  1  1  ...   1   1   3   2   1   2   1
# 1      STUDENT2  2  2  3  3  1  2  2  1  1  ...   1   1   3   2   3   2   2
# 2      STUDENT3  2  2  2  3  2  2  2  2  4  ...   1   1   2   2   1   1   2
# 3      STUDENT4  1  1  1  3  1  2  1  2  1  ...   1   2   3   2   2   1   3
# 4      STUDENT5  2  2  1  3  2  2  1  3  1  ...   2   1   2   2   2   1   2
# 5      STUDENT6  2  2  2  3  2  2  2  2  1  ...   1   1   1   2   1   2   4
# 6      STUDENT7  1  2  2  4  2  2  2  1  1  ...   1   1   3   3   3   3   4
# 7      STUDENT8  1  1  2  3  1  1  1  2  2  ...   3   1   3   2   2   1   1
# 8      STUDENT9  2  1  3  3  2  1  1  1  1  ...   1   1   3   2   2   2   4
# 9     STUDENT10  2  1  2  3  2  2  1  3  4  ...   1   1   2   2   2   2   1
# 10    STUDENT11  1  1  1  3  2  2  2  3  2  ...   1   1   2   2   2   2   1
# ...

# %%
#print out csv reader material

# %%
# Create function returning a compiled network that builds NN model
def create_network():
    
    # Start neural network
    network = models.Sequential()

    # Add fully connected layer with a ReLU activation function
    network.add(layers.Dense(units=16, activation='sigmoid', input_shape=(number_of_features,)))

    network.add(layers.Dense(units=16, activation='sigmoid'))

    network.add(layers.Dense(units=1, activation='sigmoid'))

    # Compile neural network
    network.compile(loss='binary_crossentropy', # Cross-entropy
                    optimizer='rmsprop', # Root Mean Square Propagation
                    metrics=['accuracy']) # Accuracy performance metric
    
    # Return compiled network
    return network

# %%
# Wrap Keras model so it can be used by scikit-learn
neural_network = KerasClassifier(build_fn=create_network, 
                                 epochs=10, 
                                 batch_size=100, 
                                 verbose=0)

# %%
# Number of features
number_of_features = 30

# Generate features matrix and target vector
features, target = make_classification(n_samples = 10000,
                                       n_features = number_of_features,
                                       n_informative = 3,
                                       n_redundant = 0,
                                       n_classes = 2,
                                       weights = [.5, .5],
                                       random_state = 0)

# %%
from keras.models import Sequential
from keras.layers import Dense

model = keras.models.Sequential() 
model.add(keras.layers.Dense(units = 64, activation = 'relu', input_shape = (1, 5)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(units = 1, activation = 'linear'))
model.compile(loss='mean_absolute_error', 
                optimizer='adam', 
                metrics=['accuracy'])

# %%
# Evaluate neural network using ten-fold cross-validation
#tranverse 
X_train = []
X_test = []
Y_train = []
Y_test = []



for i in range(130):
    temp = []
    for j in data.keys()[1:31]:
        temp.append(data[j][i])
        
    X_train.append(temp)
    
for i in range(130,145):
    temp = []
    for j in data.keys()[1:31]:
        temp.append(data[j][i])
        
    X_test.append(temp)
    
    
Y_train = data['GRADE'][:130]
Y_test = data['GRADE'][130:145]

    
#Y = data['GRADE']

#for i in data.keys():
 #   print(data[i])
    #X.append(data[i])
#Y = data[:'GRADE']

#data.keys()
#cross_val_score(neural_network, X, Y, cv=10).mean()
# Out:
# 15

# %%
# MLP with manual validation set

model.add(Dense(12, input_dim=8, activation='sigmoid'))
model.add(Dense(8, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))
model.fit(X_train, Y_train, validation_data=(X_test,Y_test), epochs=150, batch_size=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-7b8d2dea6c33> in <module>
#       4 model.add(Dense(8, activation='sigmoid'))
#       5 model.add(Dense(1, activation='sigmoid'))
# ----> 6 model.fit(X_train, Y_train, validation_data=(X_test,Y_test), epochs=150, batch_size=10)
#
# ~\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in select_data_adapter(x, y)
#     985         "Failed to find data adapter that can handle "
#     986         "input: {}, {}".format(
# ...

# %%
cross_val_score(neural_network, X, Y, cv=20).mean()
# Out:
# C:\Users\taile\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:680: UserWarning: The least populated class in y has only 8 members, which is less than n_splits=20.
#   UserWarning,
# C:\Users\taile\Anaconda3\lib\site-packages\scikeras\wrappers.py:290: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   "``build_fn`` will be renamed to ``model`` in a future release,"
# C:\Users\taile\Anaconda3\lib\site-packages\scikeras\wrappers.py:290: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   "``build_fn`` will be renamed to ``model`` in a future release,"
# C:\Users\taile\Anaconda3\lib\site-packages\scikeras\wrappers.py:290: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
# ...

# %%
cross_val_score(neural_network, X_train, Y_train, cv = 10).mean()
# Out:
# C:\Users\taile\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:680: UserWarning: The least populated class in y has only 5 members, which is less than n_splits=10.
#   UserWarning,
# C:\Users\taile\Anaconda3\lib\site-packages\scikeras\wrappers.py:290: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   "``build_fn`` will be renamed to ``model`` in a future release,"
# C:\Users\taile\Anaconda3\lib\site-packages\scikeras\wrappers.py:290: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   "``build_fn`` will be renamed to ``model`` in a future release,"
# C:\Users\taile\Anaconda3\lib\site-packages\scikeras\wrappers.py:290: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
# ...

# %%
cross_val_score(neural_network, X_test, Y_test, cv = 3).mean()
# Out:
# C:\Users\taile\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:680: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=3.
#   UserWarning,
# C:\Users\taile\Anaconda3\lib\site-packages\scikeras\wrappers.py:290: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   "``build_fn`` will be renamed to ``model`` in a future release,"
# C:\Users\taile\Anaconda3\lib\site-packages\scikeras\wrappers.py:290: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   "``build_fn`` will be renamed to ``model`` in a future release,"
# C:\Users\taile\Anaconda3\lib\site-packages\scikeras\wrappers.py:290: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
# ...

# %%
file.close()
